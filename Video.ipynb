# %% [markdown]
# # Gemini API: Prompting with Video

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Video.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# This notebook provides a quick example of how to prompt Gemini 1.5 Pro using a video file. In this case, you'll use a short clip of [Big Buck Bunny](https://peach.blender.org/about/).

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
# !pip install -U -q google-generativeai
# !pip install -qq pyannote.audio==3.1.1
# !pip install -qq ipython==7.34.0
# !wget -q "https://github.com/pyannote/pyannote-audio/raw/develop/tutorials/assets/sample.wav"
# !wget -q "https://github.com/pyannote/pyannote-audio/raw/develop/tutorials/assets/sample.rttm"
# !wget -q -P ./assets/ "https://github.com/pyannote/pyannote-audio/blob/develop/tutorials/assets/download-model.png"
# !wget -q -P ./assets/ "https://github.com/pyannote/pyannote-audio/blob/develop/tutorials/assets/download-pipeline.png"
# Out:
# Collecting h5py
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting numpy>=1.17.3
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy, h5py
# Successfully installed h5py-3.11.0 numpy-1.26.4
# Requirement already satisfied: typing-extensions in ./env/lib/python3.10/site-packages (4.11.0)
# Collecting wheel
#   Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 KB 775.6 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: wheel
# Successfully installed wheel-0.43.0

# %%
import google.generativeai as genai

# %% [markdown]
# ### Authentication Overview
#
# **Important:** The File API uses API keys for authentication and access. Uploaded files are associated with the API key's cloud project. Unlike other Gemini APIs that use API keys, your API key also grants access data you've uploaded to the File API, so take extra care in keeping your API key secure. For best practices on securing API keys, refer to Google's [documentation](https://support.google.com/googleapi/answer/6310037).

# %% [markdown]
# ### Setup your API key
#
# To run the following cell, your API key must be stored it in a Colab Secret named `GOOGLE_API_KEY`. If you don't already have an API key, or you're not sure how to create a Colab Secret, see [Authentication](https://github.com/google-gemini/cookbook/blob/main/quickstarts/Authentication.ipynb) for an example.

# %%
GOOGLE_API_KEY=''
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Extract frames
#
# The Gemini API currently does not support video files directly. Instead, you can provide a series of timestamps and image files.
#
# We will extract 1 frame a second from a the short film "Big Buck Bunny" file using [OpenCV](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html).
#
# > "Big Buck Bunny" is (c) copyright 2008, Blender Foundation / www.bigbuckbunny.org and [licensed](https://peach.blender.org/about/) under the [Creative Commons Attribution 3.0](http://creativecommons.org/licenses/by/3.0/) License.
#
# Note: You can also [upload your own files](https://github.com/google-gemini/cookbook/tree/main/examples/Upload_files.ipynb) to use.

# %%
video_file_name = "DG Check-in-20230705_084639-Meeting Recording (online-video-cutter.com) (1).mp4"

# %% [markdown]
# Use OpenCV to extract image frames from the video at 1 frame per second.

# %%
import cv2
import os
import shutil

# Create or cleanup existing extracted image frames directory.
FRAME_EXTRACTION_DIRECTORY = "frames"
FRAME_PREFIX = "_frame"
def create_frame_output_dir(output_dir):
  if not os.path.exists(output_dir):
    os.makedirs(output_dir)
  else:
    shutil.rmtree(output_dir)
    os.makedirs(output_dir)

def extract_frame_from_video(video_file_path):
  print(f"Extracting {video_file_path} at 1 frame per second. This might take a bit...")
  create_frame_output_dir(FRAME_EXTRACTION_DIRECTORY)
  vidcap = cv2.VideoCapture(video_file_path)
  fps = vidcap.get(cv2.CAP_PROP_FPS)
  frame_duration = 1 / fps  # Time interval between frames (in seconds)
  output_file_prefix = os.path.basename(video_file_path).replace('.', '_')
  frame_count = 0
  count = 0
  while vidcap.isOpened():
      success, frame = vidcap.read()
      if not success: # End of video
          break
      if int(count / fps) == frame_count: # Extract a frame every second
          min = frame_count // 60
          sec = frame_count % 60
          time_string = f"{min:02d}:{sec:02d}"
          image_name = f"{output_file_prefix}{FRAME_PREFIX}{time_string}.jpg"
          output_filename = os.path.join(FRAME_EXTRACTION_DIRECTORY, image_name)
          cv2.imwrite(output_filename, frame)
          frame_count += 1
      count += 1
  vidcap.release() # Release the capture object\n",
  print(f"Completed video frame extraction!\n\nExtracted: {frame_count} frames")

extract_frame_from_video(video_file_name)
# Out:
# Extracting DG Check-in-20230705_084639-Meeting Recording (online-video-cutter.com) (1).mp4 at 1 frame per second. This might take a bit...
# Completed video frame extraction!
#
# Extracted: 271 frames

# %% [markdown]
# ## Upload frames using the File API
#
# Once we have the frames extracted, we are ready to upload the frames to the API.
#
# The File API accepts files under 2GB in size and can store up to 20GB of files per project. Files last for 2 days and cannot be downloaded from the API.
#
# We will just upload 10 frames so this example runs quickly. You can modify the code below to upload the entire video.

# %%
import os

class File:
  def __init__(self, file_path: str, display_name: str = None):
    self.file_path = file_path
    if display_name:
      self.display_name = display_name
    self.timestamp = get_timestamp(file_path)

  def set_file_response(self, response):
    self.response = response

def get_timestamp(filename):
  """Extracts the frame count (as an integer) from a filename with the format
     'output_file_prefix_frame00:00.jpg'.
  """
  parts = filename.split(FRAME_PREFIX)
  if len(parts) != 2:
      return None  # Indicates the filename might be incorrectly formatted
  return parts[1].split('.')[0]

# Process each frame in the output directory
files = os.listdir(FRAME_EXTRACTION_DIRECTORY)
files = sorted(files)
files_to_upload = []
for file in files:
  files_to_upload.append(
      File(file_path=os.path.join(FRAME_EXTRACTION_DIRECTORY, file)))

# Upload the files to the API
# Only upload a 10 second slice of files to reduce upload time.
# Change full_video to True to upload the whole video.
full_video = True

uploaded_files = []
print(f'Uploading {len(files_to_upload) if full_video else 10} files. This might take a bit...')

for file in files_to_upload if full_video else files_to_upload[40:50]:
  print(f'Uploading: {file.file_path}...')
  response = genai.upload_file(path=file.file_path)
  file.set_file_response(response)
  uploaded_files.append(file)

print(f"Completed file uploads!\n\nUploaded: {len(uploaded_files)} files")
# Out:
# Uploading 271 files. This might take a bit...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:00.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:01.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:02.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:03.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:04.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:05.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:06.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:07.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:08.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:09.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:10.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:11.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:12.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:13.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:14.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:15.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:16.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:17.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:18.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:19.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:20.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:21.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:22.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:23.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:24.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:25.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:26.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:27.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:28.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:29.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:30.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:31.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:32.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:33.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:34.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:35.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:36.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:37.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:38.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:39.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:40.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:41.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:42.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:43.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:44.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:45.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:46.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:47.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:48.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:49.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:50.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:51.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:52.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:53.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:54.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:55.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:56.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:57.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:58.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame00:59.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:00.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:01.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:02.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:03.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:04.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:05.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:06.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:07.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:08.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:09.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:10.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:11.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:12.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:13.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:14.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:15.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:16.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:17.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:18.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:19.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:20.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:21.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:22.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:23.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:24.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:25.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:26.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:27.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:28.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:29.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:30.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:31.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:32.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:33.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:34.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:35.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:36.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:37.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:38.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:39.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:40.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:41.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:42.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:43.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:44.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:45.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:46.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:47.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:48.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:49.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:50.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:51.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:52.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:53.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:54.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:55.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:56.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:57.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:58.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame01:59.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:00.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:01.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:02.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:03.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:04.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:05.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:06.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:07.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:08.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:09.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:10.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:11.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:12.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:13.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:14.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:15.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:16.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:17.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:18.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:19.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:20.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:21.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:22.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:23.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:24.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:25.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:26.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:27.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:28.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:29.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:30.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:31.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:32.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:33.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:34.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:35.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:36.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:37.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:38.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:39.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:40.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:41.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:42.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:43.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:44.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:45.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:46.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:47.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:48.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:49.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:50.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:51.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:52.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:53.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:54.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:55.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:56.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:57.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:58.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame02:59.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:00.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:01.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:02.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:03.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:04.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:05.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:06.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:07.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:08.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:09.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:10.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:11.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:12.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:13.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:14.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:15.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:16.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:17.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:18.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:19.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:20.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:21.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:22.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:23.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:24.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:25.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:26.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:27.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:28.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:29.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:30.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:31.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:32.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:33.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:34.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:35.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:36.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:37.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:38.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:39.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:40.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:41.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:42.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:43.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:44.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:45.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:46.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:47.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:48.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:49.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:50.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:51.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:52.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:53.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:54.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:55.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:56.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:57.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:58.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame03:59.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:00.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:01.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:02.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:03.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:04.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:05.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:06.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:07.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:08.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:09.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:10.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:11.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:12.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:13.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:14.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:15.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:16.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:17.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:18.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:19.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:20.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:21.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:22.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:23.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:24.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:25.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:26.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:27.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:28.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:29.jpg...
# Uploading: frames/DG Check-in-20230705_084639-Meeting Recording (online-video-cutter_com) (1)_mp4_frame04:30.jpg...
# Completed file uploads!
#
# Uploaded: 271 files

# %% [markdown]
# ## List Files
#
# After uploading the file, you can verify the API has successfully received the files by calling `files.list`.
#
# `files.list` lets you see all files that have been uploaded to the File API that are associated with the Cloud project your API key belongs to. Only the `name` (and by extension, the `uri`) are unique.

# %%
# List files uploaded in the API
for n, f in zip(range(len(uploaded_files)), genai.list_files()):
  print(f.uri)
# Out:
# https://generativelanguage.googleapis.com/v1beta/files/q6lm3az0psvk
# https://generativelanguage.googleapis.com/v1beta/files/6h08tphddk39
# https://generativelanguage.googleapis.com/v1beta/files/jxiho2av7dln
# https://generativelanguage.googleapis.com/v1beta/files/3b41m5ceoyf3
# https://generativelanguage.googleapis.com/v1beta/files/s0qags8me65n
# https://generativelanguage.googleapis.com/v1beta/files/b8jn9j19ff5
# https://generativelanguage.googleapis.com/v1beta/files/ymbkhsaa1md3
# https://generativelanguage.googleapis.com/v1beta/files/glipci61f84o
# https://generativelanguage.googleapis.com/v1beta/files/u2nnot9yiqwi
# https://generativelanguage.googleapis.com/v1beta/files/fl4j57a6kyx4
# https://generativelanguage.googleapis.com/v1beta/files/wp9vpdc90i75
# https://generativelanguage.googleapis.com/v1beta/files/5pqr0dg1egoc
# https://generativelanguage.googleapis.com/v1beta/files/dr3dmr455yn2
# https://generativelanguage.googleapis.com/v1beta/files/2qdj8lae771v
# https://generativelanguage.googleapis.com/v1beta/files/kv0qbmhlqr67
# https://generativelanguage.googleapis.com/v1beta/files/o5nwidi5e8ub
# https://generativelanguage.googleapis.com/v1beta/files/epjzu27ua58z
# https://generativelanguage.googleapis.com/v1beta/files/mk0zskn9wl5c
# https://generativelanguage.googleapis.com/v1beta/files/zy73fk507sa7
# https://generativelanguage.googleapis.com/v1beta/files/rqn9i7g3na4d
# https://generativelanguage.googleapis.com/v1beta/files/t7ttzhrws032
# https://generativelanguage.googleapis.com/v1beta/files/d4l9nr822r0l
# https://generativelanguage.googleapis.com/v1beta/files/wafyci4v5c4y
# https://generativelanguage.googleapis.com/v1beta/files/tn1yepj93py4
# https://generativelanguage.googleapis.com/v1beta/files/rx6weih50au
# https://generativelanguage.googleapis.com/v1beta/files/i2f980kz3fad
# https://generativelanguage.googleapis.com/v1beta/files/w78mbk16tmbv
# https://generativelanguage.googleapis.com/v1beta/files/a82g3u425k8u
# https://generativelanguage.googleapis.com/v1beta/files/e2y87tothgsf
# https://generativelanguage.googleapis.com/v1beta/files/luyvdk4fx9if
# https://generativelanguage.googleapis.com/v1beta/files/szhd2v7dpjt
# https://generativelanguage.googleapis.com/v1beta/files/8bds1xwe1fjx
# https://generativelanguage.googleapis.com/v1beta/files/8r2vmlstcoae
# https://generativelanguage.googleapis.com/v1beta/files/3yh1o9awpbhw
# https://generativelanguage.googleapis.com/v1beta/files/1qbieytuhjda
# https://generativelanguage.googleapis.com/v1beta/files/hu9hcwaiv6lv
# https://generativelanguage.googleapis.com/v1beta/files/5y7pbpc0cdkx
# https://generativelanguage.googleapis.com/v1beta/files/97ay4o3p7buy
# https://generativelanguage.googleapis.com/v1beta/files/63k5wqhbb4nj
# https://generativelanguage.googleapis.com/v1beta/files/61uv800yyl04
# https://generativelanguage.googleapis.com/v1beta/files/6qj79vxe47ik
# https://generativelanguage.googleapis.com/v1beta/files/4w3chvqs6itn
# https://generativelanguage.googleapis.com/v1beta/files/hx6kowsahh2d
# https://generativelanguage.googleapis.com/v1beta/files/le9x60zzw5na
# https://generativelanguage.googleapis.com/v1beta/files/ut1sv5u8cyal
# https://generativelanguage.googleapis.com/v1beta/files/ue85vql3tfhv
# https://generativelanguage.googleapis.com/v1beta/files/fnsrg7h3vage
# https://generativelanguage.googleapis.com/v1beta/files/aw8krystvtjy
# https://generativelanguage.googleapis.com/v1beta/files/fw3da1dbfaj0
# https://generativelanguage.googleapis.com/v1beta/files/ik77czagliqn
# https://generativelanguage.googleapis.com/v1beta/files/hyn2id6qz45t
# https://generativelanguage.googleapis.com/v1beta/files/4w1it6pgs8os
# https://generativelanguage.googleapis.com/v1beta/files/vwwsgyv6e1tu
# https://generativelanguage.googleapis.com/v1beta/files/qknggl6ahdv2
# https://generativelanguage.googleapis.com/v1beta/files/i6xp0t5dxms
# https://generativelanguage.googleapis.com/v1beta/files/ncv82c8nyv36
# https://generativelanguage.googleapis.com/v1beta/files/rqqf4ty691jm
# https://generativelanguage.googleapis.com/v1beta/files/ysu2hpye0421
# https://generativelanguage.googleapis.com/v1beta/files/oicd16fnznv
# https://generativelanguage.googleapis.com/v1beta/files/vxql2eyr0hfy
# https://generativelanguage.googleapis.com/v1beta/files/16ml397z49eo
# https://generativelanguage.googleapis.com/v1beta/files/dp1q3zuufkxv
# https://generativelanguage.googleapis.com/v1beta/files/1ka14c8fgjw9
# https://generativelanguage.googleapis.com/v1beta/files/tjk8pzzkgwmn
# https://generativelanguage.googleapis.com/v1beta/files/itn083ferdjk
# https://generativelanguage.googleapis.com/v1beta/files/9pvldjsytop5
# https://generativelanguage.googleapis.com/v1beta/files/vjscbx62bu4m
# https://generativelanguage.googleapis.com/v1beta/files/873ingsybrsa
# https://generativelanguage.googleapis.com/v1beta/files/8qhzsh8amsyt
# https://generativelanguage.googleapis.com/v1beta/files/pyvqqcsb4uk6
# https://generativelanguage.googleapis.com/v1beta/files/i928vfvchhni
# https://generativelanguage.googleapis.com/v1beta/files/wov76fdg2jtg
# https://generativelanguage.googleapis.com/v1beta/files/jugtvgo96o8w
# https://generativelanguage.googleapis.com/v1beta/files/9fiiopsihc02
# https://generativelanguage.googleapis.com/v1beta/files/b8qv6p25jc2k
# https://generativelanguage.googleapis.com/v1beta/files/60j9e9vkmgz0
# https://generativelanguage.googleapis.com/v1beta/files/xallq3o348e7
# https://generativelanguage.googleapis.com/v1beta/files/wq5t6n7qlsih
# https://generativelanguage.googleapis.com/v1beta/files/p74fav2mywjr
# https://generativelanguage.googleapis.com/v1beta/files/l3mc0hwafdi9
# https://generativelanguage.googleapis.com/v1beta/files/wrc3s72n5prm
# https://generativelanguage.googleapis.com/v1beta/files/z98keiz0oe6v
# https://generativelanguage.googleapis.com/v1beta/files/aqg51840x9u1
# https://generativelanguage.googleapis.com/v1beta/files/cxux9adkvvfo
# https://generativelanguage.googleapis.com/v1beta/files/hj00u8a5woni
# https://generativelanguage.googleapis.com/v1beta/files/bce469u7i8cu
# https://generativelanguage.googleapis.com/v1beta/files/564byfz585uc
# https://generativelanguage.googleapis.com/v1beta/files/5l0y6fg1cvjb
# https://generativelanguage.googleapis.com/v1beta/files/wcqdm8jefm3l
# https://generativelanguage.googleapis.com/v1beta/files/weibzjiygeih
# https://generativelanguage.googleapis.com/v1beta/files/4cnjbmuomv6n
# https://generativelanguage.googleapis.com/v1beta/files/5czb0kg16mco
# https://generativelanguage.googleapis.com/v1beta/files/sqdyheitblpb
# https://generativelanguage.googleapis.com/v1beta/files/6cy5zxv5wgi7
# https://generativelanguage.googleapis.com/v1beta/files/sy5g3jdy3l2i
# https://generativelanguage.googleapis.com/v1beta/files/xmfrdz5fahde
# https://generativelanguage.googleapis.com/v1beta/files/s3e7ur8xqgd4
# https://generativelanguage.googleapis.com/v1beta/files/heax7g9o1dv0
# https://generativelanguage.googleapis.com/v1beta/files/7st406zi1jpq
# https://generativelanguage.googleapis.com/v1beta/files/nve612xyq991
# https://generativelanguage.googleapis.com/v1beta/files/rft5ssyx64nh
# https://generativelanguage.googleapis.com/v1beta/files/bl6x7cddt84u
# https://generativelanguage.googleapis.com/v1beta/files/7k0ek517wful
# https://generativelanguage.googleapis.com/v1beta/files/f28lea09gh9v
# https://generativelanguage.googleapis.com/v1beta/files/qa6w8a7mcmrw
# https://generativelanguage.googleapis.com/v1beta/files/ckckjxvckt41
# https://generativelanguage.googleapis.com/v1beta/files/7dm2k0omsb0u
# https://generativelanguage.googleapis.com/v1beta/files/rf4f39kioh73
# https://generativelanguage.googleapis.com/v1beta/files/katoz8m43exh
# https://generativelanguage.googleapis.com/v1beta/files/mdbu6qo66qwu
# https://generativelanguage.googleapis.com/v1beta/files/o6fv4j8acxix
# https://generativelanguage.googleapis.com/v1beta/files/yholawctzxxy
# https://generativelanguage.googleapis.com/v1beta/files/vmz2uglkmly2
# https://generativelanguage.googleapis.com/v1beta/files/prgxradcwdh8
# https://generativelanguage.googleapis.com/v1beta/files/gu3rfenuzpsn
# https://generativelanguage.googleapis.com/v1beta/files/cthqk7h8bygp
# https://generativelanguage.googleapis.com/v1beta/files/crgn5hni9x7b
# https://generativelanguage.googleapis.com/v1beta/files/wmmpjcpz0eci
# https://generativelanguage.googleapis.com/v1beta/files/zet5fgdg78vt
# https://generativelanguage.googleapis.com/v1beta/files/n1a6kw89ekos
# https://generativelanguage.googleapis.com/v1beta/files/hmsxg8j4zklc
# https://generativelanguage.googleapis.com/v1beta/files/wdccu4txq1rl
# https://generativelanguage.googleapis.com/v1beta/files/5l9q3k5f3nrf
# https://generativelanguage.googleapis.com/v1beta/files/jvdri5chmegf
# https://generativelanguage.googleapis.com/v1beta/files/um0lkheki5xn
# https://generativelanguage.googleapis.com/v1beta/files/4ml9djxn15df
# https://generativelanguage.googleapis.com/v1beta/files/b0fy74s53xym
# https://generativelanguage.googleapis.com/v1beta/files/1ypnd0konowv
# https://generativelanguage.googleapis.com/v1beta/files/ioftngdp2wpj
# https://generativelanguage.googleapis.com/v1beta/files/tawtvu7f0fbf
# https://generativelanguage.googleapis.com/v1beta/files/f4hx3ejzqpd5
# https://generativelanguage.googleapis.com/v1beta/files/j82zanpv762y
# https://generativelanguage.googleapis.com/v1beta/files/62zg7sza4xgv
# https://generativelanguage.googleapis.com/v1beta/files/1ijzcepz3i5i
# https://generativelanguage.googleapis.com/v1beta/files/chbye77cpjp9
# https://generativelanguage.googleapis.com/v1beta/files/hlivtumj3o7z
# https://generativelanguage.googleapis.com/v1beta/files/gfpfne8842zf
# https://generativelanguage.googleapis.com/v1beta/files/mq4yagkn90h3
# https://generativelanguage.googleapis.com/v1beta/files/gykmzqbbzrer
# https://generativelanguage.googleapis.com/v1beta/files/f0klgzhqzsf5
# https://generativelanguage.googleapis.com/v1beta/files/tyswpkkpz3sq
# https://generativelanguage.googleapis.com/v1beta/files/s3qu3uvmk7yv
# https://generativelanguage.googleapis.com/v1beta/files/rpdb2rj6erdn
# https://generativelanguage.googleapis.com/v1beta/files/icpngwxga22b
# https://generativelanguage.googleapis.com/v1beta/files/s3trukx42vm5
# https://generativelanguage.googleapis.com/v1beta/files/v7lr61li4k4f
# https://generativelanguage.googleapis.com/v1beta/files/p3wckvk6bkm5
# https://generativelanguage.googleapis.com/v1beta/files/navd6jqrek8t
# https://generativelanguage.googleapis.com/v1beta/files/ddhbtu58b7gx
# https://generativelanguage.googleapis.com/v1beta/files/fqbd6k4ua0n7
# https://generativelanguage.googleapis.com/v1beta/files/sg9mj578jr66
# https://generativelanguage.googleapis.com/v1beta/files/84im5sjntjiq
# https://generativelanguage.googleapis.com/v1beta/files/icvqw8kunner
# https://generativelanguage.googleapis.com/v1beta/files/21s4kbnvg5ws
# https://generativelanguage.googleapis.com/v1beta/files/fmnn7aqmi11r
# https://generativelanguage.googleapis.com/v1beta/files/2h31y63lc2vy
# https://generativelanguage.googleapis.com/v1beta/files/t93zrdj89eiq
# https://generativelanguage.googleapis.com/v1beta/files/npgfd3xr1yuq
# https://generativelanguage.googleapis.com/v1beta/files/afnjpfzn4tad
# https://generativelanguage.googleapis.com/v1beta/files/m91qwqyrlo0f
# https://generativelanguage.googleapis.com/v1beta/files/mavyvjs3d1fj
# https://generativelanguage.googleapis.com/v1beta/files/16s1sqb97c6v
# https://generativelanguage.googleapis.com/v1beta/files/q6c340wgddbq
# https://generativelanguage.googleapis.com/v1beta/files/702h0r2f7x6z
# https://generativelanguage.googleapis.com/v1beta/files/gcl72uejglld
# https://generativelanguage.googleapis.com/v1beta/files/r2qo2xjtaqy4
# https://generativelanguage.googleapis.com/v1beta/files/vyf2c97ewxl8
# https://generativelanguage.googleapis.com/v1beta/files/9ufb875n6lxt
# https://generativelanguage.googleapis.com/v1beta/files/ws1e8e593d0r
# https://generativelanguage.googleapis.com/v1beta/files/4rupzdcu9vd2
# https://generativelanguage.googleapis.com/v1beta/files/hmzdmml32uue
# https://generativelanguage.googleapis.com/v1beta/files/9nh73cynowjv
# https://generativelanguage.googleapis.com/v1beta/files/8ogve855h681
# https://generativelanguage.googleapis.com/v1beta/files/viv0wgzbwiu7
# https://generativelanguage.googleapis.com/v1beta/files/sfx39c49tyrw
# https://generativelanguage.googleapis.com/v1beta/files/cdb53rwq1mgc
# https://generativelanguage.googleapis.com/v1beta/files/rfst2tog62me
# https://generativelanguage.googleapis.com/v1beta/files/vgr9593b3joh
# https://generativelanguage.googleapis.com/v1beta/files/mkdx1jv8ig7x
# https://generativelanguage.googleapis.com/v1beta/files/s7tdnlr216a
# https://generativelanguage.googleapis.com/v1beta/files/jptq729souod
# https://generativelanguage.googleapis.com/v1beta/files/staku19esu63
# https://generativelanguage.googleapis.com/v1beta/files/86wi0h51ubun
# https://generativelanguage.googleapis.com/v1beta/files/8rr2vnpu5vhq
# https://generativelanguage.googleapis.com/v1beta/files/m4u1ccfh9h38
# https://generativelanguage.googleapis.com/v1beta/files/s23mzp6p9cyv
# https://generativelanguage.googleapis.com/v1beta/files/dmsn8a4cwnig
# https://generativelanguage.googleapis.com/v1beta/files/vfydwieuwg9b
# https://generativelanguage.googleapis.com/v1beta/files/ammrsmf8fj9c
# https://generativelanguage.googleapis.com/v1beta/files/c3h4jcmesmke
# https://generativelanguage.googleapis.com/v1beta/files/ietu1eek09ir
# https://generativelanguage.googleapis.com/v1beta/files/rtvp6u502ig5
# https://generativelanguage.googleapis.com/v1beta/files/87e9oj5ptp0o
# https://generativelanguage.googleapis.com/v1beta/files/l4pe343nsq4h
# https://generativelanguage.googleapis.com/v1beta/files/d8fyksmpreda
# https://generativelanguage.googleapis.com/v1beta/files/psluqjebkui6
# https://generativelanguage.googleapis.com/v1beta/files/uzo6cz0mdm91
# https://generativelanguage.googleapis.com/v1beta/files/gnfi26bp0xw8
# https://generativelanguage.googleapis.com/v1beta/files/uqkiedg20duv
# https://generativelanguage.googleapis.com/v1beta/files/ihgqnab2qz1f
# https://generativelanguage.googleapis.com/v1beta/files/btrxnfv1c6yt
# https://generativelanguage.googleapis.com/v1beta/files/3nmddmkj4dj5
# https://generativelanguage.googleapis.com/v1beta/files/48il6c53x3po
# https://generativelanguage.googleapis.com/v1beta/files/koigxx3wtnfb
# https://generativelanguage.googleapis.com/v1beta/files/cvehg1g1vpw8
# https://generativelanguage.googleapis.com/v1beta/files/zbdvbfetug0j
# https://generativelanguage.googleapis.com/v1beta/files/19em9ypuhih6
# https://generativelanguage.googleapis.com/v1beta/files/r87fud0ydpj5
# https://generativelanguage.googleapis.com/v1beta/files/ofa9zgdi6yn9
# https://generativelanguage.googleapis.com/v1beta/files/2xuil3mkt06r
# https://generativelanguage.googleapis.com/v1beta/files/1cv3cnobv15g
# https://generativelanguage.googleapis.com/v1beta/files/fut94vu6ibaz
# https://generativelanguage.googleapis.com/v1beta/files/tgbgw9tbbw3n
# https://generativelanguage.googleapis.com/v1beta/files/olujgczoyd5k
# https://generativelanguage.googleapis.com/v1beta/files/4hzgkgi6az7g
# https://generativelanguage.googleapis.com/v1beta/files/bdnzkaca7ey1
# https://generativelanguage.googleapis.com/v1beta/files/zvxjexkmtern
# https://generativelanguage.googleapis.com/v1beta/files/kbc0m5ym0ke8
# https://generativelanguage.googleapis.com/v1beta/files/v8m68pnwgwci
# https://generativelanguage.googleapis.com/v1beta/files/bsaw2sa0m128
# https://generativelanguage.googleapis.com/v1beta/files/5vksi7emkg4t
# https://generativelanguage.googleapis.com/v1beta/files/ticbo4ex1spu
# https://generativelanguage.googleapis.com/v1beta/files/kp8mnnjl5126
# https://generativelanguage.googleapis.com/v1beta/files/e8mk22c7wx8e
# https://generativelanguage.googleapis.com/v1beta/files/hkmsrjzkadp9
# https://generativelanguage.googleapis.com/v1beta/files/lhlkecmool4x
# https://generativelanguage.googleapis.com/v1beta/files/qysei1t1korh
# https://generativelanguage.googleapis.com/v1beta/files/ip5d8k0464rn
# https://generativelanguage.googleapis.com/v1beta/files/x6jzcgc1jd7x
# https://generativelanguage.googleapis.com/v1beta/files/m9r1bsq0wv72
# https://generativelanguage.googleapis.com/v1beta/files/pi7mtpleblwn
# https://generativelanguage.googleapis.com/v1beta/files/9xftze0f945w
# https://generativelanguage.googleapis.com/v1beta/files/w372qlyaammp
# https://generativelanguage.googleapis.com/v1beta/files/xpyrl5plcr7c
# https://generativelanguage.googleapis.com/v1beta/files/5s52beve3d8g
# https://generativelanguage.googleapis.com/v1beta/files/j9rhtc86hviv
# https://generativelanguage.googleapis.com/v1beta/files/d1z5vncskyz2
# https://generativelanguage.googleapis.com/v1beta/files/nbms437np2ts
# https://generativelanguage.googleapis.com/v1beta/files/vjxyu7ki1uvy
# https://generativelanguage.googleapis.com/v1beta/files/qw3gqy5l584o
# https://generativelanguage.googleapis.com/v1beta/files/vxz0w4t8x0yq
# https://generativelanguage.googleapis.com/v1beta/files/1cipbpku4buu
# https://generativelanguage.googleapis.com/v1beta/files/vhidfdcdc0xh
# https://generativelanguage.googleapis.com/v1beta/files/srgltt0xsz85
# https://generativelanguage.googleapis.com/v1beta/files/qh6yopdde8b0
# https://generativelanguage.googleapis.com/v1beta/files/x8u2slom8v0n
# https://generativelanguage.googleapis.com/v1beta/files/9ny28uunjcw9
# https://generativelanguage.googleapis.com/v1beta/files/carnvh0mm643
# https://generativelanguage.googleapis.com/v1beta/files/dqwfr0whvg24
# https://generativelanguage.googleapis.com/v1beta/files/m8d0unvxlikf
# https://generativelanguage.googleapis.com/v1beta/files/lyvwm0inxsbq
# https://generativelanguage.googleapis.com/v1beta/files/f0j4u45iy42t
# https://generativelanguage.googleapis.com/v1beta/files/9hjphhbg36ko
# https://generativelanguage.googleapis.com/v1beta/files/grm56pp4fu9m
# https://generativelanguage.googleapis.com/v1beta/files/zwwiix60n03d
# https://generativelanguage.googleapis.com/v1beta/files/zehvckbkoscl
# https://generativelanguage.googleapis.com/v1beta/files/r26jkvl681bp
# https://generativelanguage.googleapis.com/v1beta/files/7a6a0il9rwt9
# https://generativelanguage.googleapis.com/v1beta/files/qkth7k2p4866
# https://generativelanguage.googleapis.com/v1beta/files/ny3tpo1hqqcc
# https://generativelanguage.googleapis.com/v1beta/files/8fsti2kyqrud
# https://generativelanguage.googleapis.com/v1beta/files/71nhv9zl4o9q
# https://generativelanguage.googleapis.com/v1beta/files/bprx8i9yay6c
# https://generativelanguage.googleapis.com/v1beta/files/atbte1mozq9z
# https://generativelanguage.googleapis.com/v1beta/files/25f129d7emmg
# https://generativelanguage.googleapis.com/v1beta/files/x43brfuf4qcg
# https://generativelanguage.googleapis.com/v1beta/files/k8l23l64dimq
# https://generativelanguage.googleapis.com/v1beta/files/wggpqawbwcen
# https://generativelanguage.googleapis.com/v1beta/files/2lsar66viugz
# https://generativelanguage.googleapis.com/v1beta/files/7karq2j7k9ly
# https://generativelanguage.googleapis.com/v1beta/files/ptxy2x7fcmoq

# %% [markdown]
# ## Generate Content
#
# After the file has been uploaded, you can make `GenerateContent` requests that reference the File API URI.
#
# To understand videos with Gemini 1.5 Pro, provide 2 consecutive `Part`s for each frame: a `text` part with the **timestamp** and `fileData` part with the frame's **image URI**:
#
# ```
# part { text = "00:00" }
# part { fileData = fileData {
#   fileUri = "https://generativelanguage.googleapis.com/v1/files/frame-0"
#   mimeType = "image/jpeg"
# }}
# ```

# %%
ROOT_DIR = "<path-to-pyannote-github-repo>/pyannote-audio"
AUDIO_FILE = "DG Check-in-20230705_084639-Meeting Recording (online-video-cutter.com) (1).wav"

# %%
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token="hugging_face_kry")

# send pipeline to GPU (when available)
import torch
pipeline.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# apply pretrained pipeline
diarization = pipeline("DG Check-in-20230705_084639-Meeting Recording (online-video-cutter.com) (1).wav")

# print the result
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
# start=0.2s stop=1.5s speaker_0
# start=1.8s stop=3.9s speaker_1
# start=4.2s stop=5.7s speaker_0
# ...
# Out:
# start=0.4s stop=2.1s speaker_SPEAKER_02
# start=6.3s stop=8.5s speaker_SPEAKER_02
# start=9.2s stop=9.9s speaker_SPEAKER_02
# start=11.5s stop=12.6s speaker_SPEAKER_02
# start=11.9s stop=12.4s speaker_SPEAKER_01
# start=13.4s stop=13.4s speaker_SPEAKER_01
# start=13.4s stop=15.2s speaker_SPEAKER_02
# start=14.0s stop=14.3s speaker_SPEAKER_01
# start=16.3s stop=17.8s speaker_SPEAKER_02
# start=18.6s stop=23.9s speaker_SPEAKER_01
# start=19.6s stop=21.0s speaker_SPEAKER_02
# start=24.7s stop=27.0s speaker_SPEAKER_01
# start=27.6s stop=32.5s speaker_SPEAKER_01
# start=34.0s stop=34.2s speaker_SPEAKER_01
# start=34.7s stop=36.0s speaker_SPEAKER_01
# start=37.8s stop=41.9s speaker_SPEAKER_01
# start=42.4s stop=45.0s speaker_SPEAKER_01
# start=43.0s stop=43.5s speaker_SPEAKER_02
# start=46.3s stop=46.7s speaker_SPEAKER_03
# start=47.9s stop=50.2s speaker_SPEAKER_03
# start=50.9s stop=52.0s speaker_SPEAKER_03
# start=55.2s stop=56.8s speaker_SPEAKER_02
# start=57.9s stop=59.2s speaker_SPEAKER_02
# start=59.3s stop=59.4s speaker_SPEAKER_02
# start=59.4s stop=60.9s speaker_SPEAKER_01
# start=62.3s stop=62.7s speaker_SPEAKER_02
# start=62.7s stop=63.2s speaker_SPEAKER_02
# start=64.3s stop=67.0s speaker_SPEAKER_01
# start=68.1s stop=80.5s speaker_SPEAKER_01
# start=80.7s stop=83.0s speaker_SPEAKER_01
# start=83.3s stop=87.5s speaker_SPEAKER_01
# start=87.9s stop=92.0s speaker_SPEAKER_01
# start=92.6s stop=94.0s speaker_SPEAKER_01
# start=94.4s stop=94.7s speaker_SPEAKER_01
# start=96.5s stop=98.8s speaker_SPEAKER_01
# start=99.3s stop=100.5s speaker_SPEAKER_01
# start=101.9s stop=104.3s speaker_SPEAKER_01
# start=104.8s stop=110.2s speaker_SPEAKER_01
# start=110.5s stop=111.6s speaker_SPEAKER_01
# start=111.9s stop=113.4s speaker_SPEAKER_01
# start=114.8s stop=116.3s speaker_SPEAKER_02
# start=115.1s stop=115.7s speaker_SPEAKER_01
# start=116.9s stop=119.6s speaker_SPEAKER_01
# start=118.8s stop=121.1s speaker_SPEAKER_00
# start=120.7s stop=121.3s speaker_SPEAKER_01
# start=121.8s stop=126.4s speaker_SPEAKER_01
# start=126.2s stop=126.7s speaker_SPEAKER_00
# start=127.1s stop=128.9s speaker_SPEAKER_01
# start=129.3s stop=130.0s speaker_SPEAKER_01
# start=130.2s stop=131.3s speaker_SPEAKER_01
# start=131.8s stop=132.6s speaker_SPEAKER_01
# start=132.7s stop=132.9s speaker_SPEAKER_01
# start=132.8s stop=133.1s speaker_SPEAKER_02
# start=133.1s stop=133.1s speaker_SPEAKER_01
# start=133.2s stop=145.5s speaker_SPEAKER_01
# start=146.6s stop=149.0s speaker_SPEAKER_01
# start=150.0s stop=150.3s speaker_SPEAKER_01
# start=151.0s stop=152.6s speaker_SPEAKER_01
# start=153.0s stop=153.4s speaker_SPEAKER_01
# start=154.3s stop=172.0s speaker_SPEAKER_01
# start=173.1s stop=173.5s speaker_SPEAKER_02
# start=173.5s stop=173.6s speaker_SPEAKER_01
# start=174.4s stop=177.8s speaker_SPEAKER_01
# start=179.3s stop=181.6s speaker_SPEAKER_01
# start=182.1s stop=187.2s speaker_SPEAKER_01
# start=188.7s stop=196.3s speaker_SPEAKER_01
# start=196.9s stop=199.0s speaker_SPEAKER_01
# start=201.0s stop=201.5s speaker_SPEAKER_02
# start=201.5s stop=206.9s speaker_SPEAKER_01
# start=207.7s stop=213.8s speaker_SPEAKER_01
# start=214.6s stop=223.6s speaker_SPEAKER_01
# start=214.9s stop=215.4s speaker_SPEAKER_00
# start=224.1s stop=229.1s speaker_SPEAKER_01
# start=232.4s stop=232.9s speaker_SPEAKER_02
# start=232.9s stop=233.0s speaker_SPEAKER_01
# start=233.0s stop=234.1s speaker_SPEAKER_02
# start=233.1s stop=233.4s speaker_SPEAKER_01
# start=235.9s stop=238.0s speaker_SPEAKER_02
# start=236.8s stop=238.0s speaker_SPEAKER_01
# start=238.0s stop=238.7s speaker_SPEAKER_01
# start=238.7s stop=238.8s speaker_SPEAKER_02
# start=238.9s stop=239.1s speaker_SPEAKER_01
# start=239.1s stop=239.2s speaker_SPEAKER_03
# start=239.2s stop=239.3s speaker_SPEAKER_01
# start=239.7s stop=239.8s speaker_SPEAKER_03
# start=239.8s stop=239.8s speaker_SPEAKER_01
# start=239.8s stop=239.9s speaker_SPEAKER_02
# start=239.9s stop=239.9s speaker_SPEAKER_03
# start=239.9s stop=240.0s speaker_SPEAKER_01
# start=240.0s stop=240.7s speaker_SPEAKER_03
# start=240.0s stop=240.6s speaker_SPEAKER_01
# start=241.0s stop=243.3s speaker_SPEAKER_03
# start=243.6s stop=244.4s speaker_SPEAKER_01
# start=244.2s stop=244.2s speaker_SPEAKER_03
# start=245.8s stop=247.9s speaker_SPEAKER_03
# start=248.9s stop=252.0s speaker_SPEAKER_01
# start=252.6s stop=253.7s speaker_SPEAKER_01
# start=253.4s stop=256.7s speaker_SPEAKER_00
# start=257.2s stop=257.8s speaker_SPEAKER_01
# start=257.8s stop=259.6s speaker_SPEAKER_01
# start=261.1s stop=261.7s speaker_SPEAKER_00
# start=261.9s stop=265.5s speaker_SPEAKER_00
# start=266.0s stop=266.5s speaker_SPEAKER_01
# start=266.2s stop=270.0s speaker_SPEAKER_00
# start=269.4s stop=269.9s speaker_SPEAKER_02
# start=270.0s stop=270.4s speaker_SPEAKER_02

# %%
audio_file = genai.upload_file(path='DG Check-in-20230705_084639-Meeting Recording (online-video-cutter.com) (1).mp3')

# %%
# Create the prompt.
prompt = "based on whose name is highlighted in the meeting (on right side of screen) at each point in the audio file, determine accurately who speaks a lot and who does not. name lighting up = speaking. also give feedback for this meeting. you have to give feedback to each member who spoke, level of participation, as well as overall meeting productivity. also note important things discussed, and possible future tasks"
#prompt = "What was the first thing said in the meeting?"
# Set the model to Gemini 1.5 Pro.
model = genai.GenerativeModel(model_name="models/gemini-1.5-pro-latest")

# Make GenerateContent request with the structure described above.
def make_request(prompt, files):
  request = [prompt]
  for file in files:
    request.append(file.timestamp)
    request.append(file.response)
  return request

# Make the LLM request.
request = make_request(prompt, uploaded_files)
request.append(audio_file)
response = model.generate_content(request,
                                  request_options={"timeout": 600})
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/grpc/_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/grpc/_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2607:f8b0:4009:81a::200a%5D:443: Network is unreachable"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2024-04-13T11:15:48.925621126-04:00", grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2607:f8b0:4009:81a::200a%5D:443: Network is unreachable"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ServiceUnavailable: 503 failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2607:f8b0:4009:81a::200a%5D:443: Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[22], line 18
#      16 request = make_request(prompt, uploaded_files)
#      17 request.append(audio_file)
# ---> 18 response = model.generate_content(request,
#      19                                   request_options={"timeout": 600})
#      20 print(response.text)
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/generativeai/generative_models.py:262, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     260         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     261     else:
# --> 262         response = self._client.generate_content(
#     263             request,
#     264             **request_options,
#     265         )
#     266         return generation_types.GenerateContentResponse.from_response(response)
#     267 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:791, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     788 self._validate_universe_domain()
#     790 # Send the request.
# --> 791 response = rpc(
#     792     request,
#     793     retry=retry,
#     794     timeout=timeout,
#     795     metadata=metadata,
#     796 )
#     798 # Done; return the response.
#     799 return response
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~/Hackathon/Google_MHACKS_AI/Google-x-MHACKS-AI-Hackathon-Gang/env/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:221, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     215 if deadline is not None and time.monotonic() + next_sleep > deadline:
#     216     final_exc, source_exc = exc_factory_fn(
#     217         error_list,
#     218         RetryFailureReason.TIMEOUT,
#     219         original_timeout,
#     220     )
# --> 221     raise final_exc from source_exc
#     222 _LOGGER.debug(
#     223     "Retrying due to {}, sleeping {:.1f}s ...".format(error_list[-1], next_sleep)
#     224 )
#
# RetryError: Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv6:%5B2607:f8b0:4009:81a::200a%5D:443: Network is unreachable

# %% [markdown]
# ## Delete Files
#
# Files are automatically deleted after 2 days or you can manually delete them using `files.delete()`.

# %%
print(f'Deleting {len(uploaded_files)} images. This might take a bit...')
for file in uploaded_files:
  genai.delete_file(file.response.name)
  print(f'Deleted {file.file_path} at URI {file.response.uri}')
print(f"Completed deleting files!\n\nDeleted: {len(uploaded_files)} files")

# %% [markdown]
# ## Learning more
#
# The File API lets you upload a variety of multimodal MIME types, including images and audio formats. The File API handles inputs that can be used to generate content with [`model.generateContent`](https://ai.google.dev/api/rest/v1/models/generateContent) or [`model.streamGenerateContent`](https://ai.google.dev/api/rest/v1/models/streamGenerateContent).
#
# The File API accepts files under 2GB in size and can store up to 20GB of files per project. Files last for 2 days and cannot be downloaded from the API.
#
# * Learn more about the [File API](https://github.com/google-gemini/cookbook/blob/main/quickstarts/File_API.ipynb) with the quickstart.
#
# * Learn more about prompting with [media files](https://ai.google.dev/tutorials/prompting_with_media) in the docs, including the supported formats and maximum length.
